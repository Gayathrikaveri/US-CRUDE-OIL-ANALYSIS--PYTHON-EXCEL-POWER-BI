# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("US crude oil Import (1).csv")
df
# Out:
#         year  month originName originTypeName  \
# 0       2009      1     Belize        Country
# 1       2009      1     Belize        Country
# 2       2009      1    Algeria        Country
# 3       2009      1    Algeria        Country
# 4       2009      1    Algeria        Country
# ...      ...    ...        ...            ...
# 483048  2024      1      World          World
# 483049  2024      1      World          World
# 483050  2024      1      World          World
# 483051  2024      1      World          World
# 483052  2024      1      World          World
#
#                                          destinationName destinationTypeName  \
# 0          EXXONMOBIL REFINING & SPLY CO / BEAUMONT / TX            Refinery
# 1                   FLINT HILLS RESOURCES LP / WEST / TX            Refinery
# 2                   SHELL OIL PRODUCTS US / ST ROSE / LA            Refinery
# 3               OIL TANKING PL INC / HOUSTON (GULF) / TX            Refinery
# 4       UNKNOWN PROCESSOR-TX / UNKNOWN PROCESSOR-TX / TX            Refinery
# ...                                                  ...                 ...
# 483048                                     United States       United States
# 483049                                     United States       United States
# 483050                                     United States       United States
# 483051                                     United States       United States
# 483052                                     United States       United States
#
#           gradeName  quantity
# 0        Light Sour        61
# 1        Light Sour        62
# 2       Light Sweet        10
# 3       Light Sweet       381
# 4       Light Sweet       851
# ...             ...       ...
# 483048   Heavy Sour    120942
# 483049  Heavy Sweet      8859
# 483050   Light Sour      7811
# 483051  Light Sweet     12553
# 483052       Medium     55237
#
# [483053 rows x 8 columns]

# %%
df.head() #head function() gives the first 5 rows
# Out:
#    year  month originName originTypeName  \
# 0  2009      1     Belize        Country
# 1  2009      1     Belize        Country
# 2  2009      1    Algeria        Country
# 3  2009      1    Algeria        Country
# 4  2009      1    Algeria        Country
#
#                                     destinationName destinationTypeName  \
# 0     EXXONMOBIL REFINING & SPLY CO / BEAUMONT / TX            Refinery
# 1              FLINT HILLS RESOURCES LP / WEST / TX            Refinery
# 2              SHELL OIL PRODUCTS US / ST ROSE / LA            Refinery
# 3          OIL TANKING PL INC / HOUSTON (GULF) / TX            Refinery
# 4  UNKNOWN PROCESSOR-TX / UNKNOWN PROCESSOR-TX / TX            Refinery
#
#      gradeName  quantity
# 0   Light Sour        61
# 1   Light Sour        62
# 2  Light Sweet        10
# 3  Light Sweet       381
# 4  Light Sweet       851

# %%
df.tail() #tail function() gives the last 5 rows
# Out:
#         year  month originName originTypeName destinationName  \
# 483048  2024      1      World          World   United States
# 483049  2024      1      World          World   United States
# 483050  2024      1      World          World   United States
# 483051  2024      1      World          World   United States
# 483052  2024      1      World          World   United States
#
#        destinationTypeName    gradeName  quantity
# 483048       United States   Heavy Sour    120942
# 483049       United States  Heavy Sweet      8859
# 483050       United States   Light Sour      7811
# 483051       United States  Light Sweet     12553
# 483052       United States       Medium     55237

# %%
df.shape #shape function() gives the number of rows and columns
# Out:
# (483053, 8)

# %%
df.columns  # Accessing column names
# Out:
# Index(['year', 'month', 'originName', 'originTypeName', 'destinationName',
#        'destinationTypeName', 'gradeName', 'quantity'],
#       dtype='object')

# %%
# Finding missing values
df.isna().sum() #isna().sum() gives the count of the missing values
# Out:
# year                   0
# month                  0
# originName             0
# originTypeName         0
# destinationName        0
# destinationTypeName    0
# gradeName              0
# quantity               0
# dtype: int64

# %%
#  Finding duplicate values
df.duplicated().sum()  #duplicated() is used to check whether any duplicated values are present
# Out:
# 0

# %%
# DATA CLEANING

# Convert the 'Year' column to a string
df['year'] = df['year'].astype(str)
df.dtypes
# Out:
# year                   object
# month                   int64
# originName             object
# originTypeName         object
# destinationName        object
# destinationTypeName    object
# gradeName              object
# quantity                int64
# dtype: object

# %%
# Defining a dictionary mapping month numbers to month names
month_names = {
    1: 'Jan',
    2: 'Feb',
    3: 'Mar',
    4: 'Apr',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'Aug',
    9: 'Sep',
    10: 'Oct',
    11: 'Nov',
    12: 'Dec'
}

# Converting the 'Month' column to strings using the map function
df['month'] = df['month'].map(month_names)
df.head(5)
# Out:
#    year month originName originTypeName  \
# 0  2009   Jan     Belize        Country
# 1  2009   Jan     Belize        Country
# 2  2009   Jan    Algeria        Country
# 3  2009   Jan    Algeria        Country
# 4  2009   Jan    Algeria        Country
#
#                                     destinationName destinationTypeName  \
# 0     EXXONMOBIL REFINING & SPLY CO / BEAUMONT / TX            Refinery
# 1              FLINT HILLS RESOURCES LP / WEST / TX            Refinery
# 2              SHELL OIL PRODUCTS US / ST ROSE / LA            Refinery
# 3          OIL TANKING PL INC / HOUSTON (GULF) / TX            Refinery
# 4  UNKNOWN PROCESSOR-TX / UNKNOWN PROCESSOR-TX / TX            Refinery
#
#      gradeName  quantity
# 0   Light Sour        61
# 1   Light Sour        62
# 2  Light Sweet        10
# 3  Light Sweet       381
# 4  Light Sweet       851

# %%
df['originName'].unique()
# Out:
# array(['Belize', 'Algeria', 'Australia', 'United Kingdom', 'Vietnam',
#        'Syria', 'Chad', 'Argentina', 'Ecuador', 'Kuwait', 'Saudi Arabia',
#        'Angola', 'Gabon', 'Trinidad and Tobago', 'China',
#        'Congo-Brazzaville', 'Colombia', 'Equatorial Guinea', 'Peru',
#        'Azerbaijan', 'Canada', 'Guatemala', 'Thailand', 'Nigeria', 'Iraq',
#        'Libya', 'Norway', 'United Arab Emirates', 'Malaysia', 'Russia',
#        'Venezuela', 'Brazil', 'Mexico', 'Africa', 'Europe',
#        'Asia-Pacific', 'Middle East', 'Eurasia', 'Other Americas',
#        'Canada (Region)', 'OPEC', 'Non-OPEC', 'World', 'Mauritania',
#        'Cameroon', 'Indonesia', 'Qatar', 'Oman', 'Egypt', "Cote d'Ivoire",
#        'Bolivia', 'Kazakhstan', 'Congo-Kinshasa', 'South Africa',
#        'Netherlands', 'Ghana', 'Yemen', 'Italy', 'Brunei', 'Albania',
#        'Denmark', 'Papua New Guinea', 'South Sudan', 'Tunisia',
#        'Barbados', 'Spain', 'Guyana', 'Panama', 'The Bahamas',
#        'Country not known'], dtype=object)

# %%
df = df[df['originName'] != 'Country not known']
df.shape
# Out:
# (483018, 8)

# %%
# Replacing 'The Bahamas' with 'Bahamas'
df.loc[df['originName'] == 'The Bahamas', 'originName'] = 'Bahamas'

# Replacing 'South Sudan' with 'Sudan' 
df.loc[df['originName'] == 'South Sudan', 'originName'] = 'Sudan'

# %%
df.describe() #gives the statistical summary
# Out:
#             quantity
# count  483018.000000
# mean     2425.353745
# std      6367.915241
# min         1.000000
# 25%       359.000000
# 50%       804.000000
# 75%      2008.000000
# max    141016.000000

# %%
value_counts = df['gradeName'].value_counts()  # Prints the value counts
value_counts
# Out:
# gradeName
# Heavy Sour     160473
# Medium         144157
# Light Sweet     79695
# Light Sour      51468
# Heavy Sweet     47225
# Name: count, dtype: int64

# %%
# Plotting the count plot
sns.countplot(data=df, x='gradeName')

# Adding labels and title
plt.xlabel('Grade Name')
plt.ylabel('Count')
plt.title('Count of Each Grade Name')

# Display the plot
plt.show()

# %%
# Detection of Outliers visually using Boxplot for the column 'Quantity'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.title('Outlier detection by boxplot')
sns.boxplot(x=df['quantity'])
# Out:
# <Axes: title={'center': 'Outlier detection by boxplot'}, xlabel='quantity'>

# %%
 # From above plot we can see that huge number of outliers are present above the upper limit.

# %%
 # Getting outliers using Tukey method (IQR method)

# Calculate Q1 and Q3
Q1 = df['quantity'].quantile(0.0)
Q3 = df['quantity'].quantile(0.506)

# Calculate IQR
IQR = Q3 - Q1


# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Get outliers
outliers= df[(df['quantity'] < lower_bound) | (df['quantity'] > upper_bound)]

# Display outliers count
print('Total Outliers detected:',len(outliers))
# Out:
# Total Outliers detected: 116432

# %% [markdown]
# What happens to that dataset if outliers are removed?

# %%
#records left if outliers are removed from the dataset
print('Before removing outliers:',len(df))
print('After removing outliers:',len(df)-len(outliers))
#percentage of data loss if outliers are removed
print('Percentage of data loss:',round((1-((len(df)-len(outliers))/len(df)))*100,2),"%")
# Out:
# Before removing outliers: 483018
# After removing outliers: 366586
# Percentage of data loss: 24.11 %

# %% [markdown]
# 1) Trimming method

# %%
# Make a copy of the original DataFrame
df_copy = df.copy()

# Calculate Q1 and Q3
Q1 = df_copy['quantity'].quantile(0.0)
Q3 = df_copy['quantity'].quantile(0.506)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers from the copy
df_no_outliers = df_copy[(df_copy['quantity'] >= lower_bound) & (df_copy['quantity'] <= upper_bound)]

# Count of records removed
print('No.of records removed:',len(df)-len(df_no_outliers))

# Display records left
print('Total records left:',len(df_no_outliers))
# Out:
# No.of records removed: 116432
# Total records left: 366586

# %%
df_no_outliers['quantity'].describe()
# Out:
# count    366586.000000
# mean        683.935311
# std         529.568813
# min           1.000000
# 25%         269.000000
# 50%         524.000000
# 75%         999.000000
# max        2071.000000
# Name: quantity, dtype: float64

# %% [markdown]
# 2)With Capping (Without removal of outliers)
#
# Capping: In capping, outliers are adjusted by replacing them with a predefined upper value (cap). This technique ensures that outliers are limited to a maximum acceptable value.

# %%
# Make a copy of the original DataFrame
df_cap=df.copy()

Q1 = df_cap['quantity'].quantile(0.0)
Q3 = df_cap['quantity'].quantile(0.55)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_cap.loc[(df_cap['quantity']>upper_bound),'quantity']=upper_bound
df_cap.loc[(df_cap['quantity']<lower_bound),'quantity']=lower_bound

# Display records left
print('Total records left:',len(df_cap))
# Out:
# Total records left: 483018

# %%
df_cap['quantity'].describe()
# Out:
# count    483018.000000
# mean       1091.037261
# std         857.727212
# min           1.000000
# 25%         359.000000
# 50%         804.000000
# 75%        2008.000000
# max        2393.500000
# Name: quantity, dtype: float64

# %% [markdown]
# 3) Flooring (Without removal of outliers)
#
# Flooring: In flooring, outliers are adjusted by replacing them with a predefined lower value (floor). This technique ensures that outliers are not completely removed but rather set to a minimum acceptable value.

# %%
# Make a copy of the original DataFrame
df_floor = df.copy()

# Define the floor threshold (lower bound)
floor_threshold = 1  # Set the threshold value above which outliers will be floored

# Floor outliers
df_floor.loc[df_floor['quantity'] > floor_threshold, 'quantity'] = floor_threshold

# Display outliers count
print('Total Outliers detected:', (df_floor['quantity'] > floor_threshold).sum())

# Display records left
print('Total records left:',len(df_floor))
# Out:
# Total Outliers detected: 0
# Total records left: 483018

# %%
df_floor['quantity'].describe()
# Out:
# count    483018.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: quantity, dtype: float64

# %% [markdown]
# 4)Tranformation using log
#
# When data is highly skewed or has a long tail, applying a logarithmic transformation can help make the distribution more symmetric and easier to analyze.

# %%
import pandas as pd
import numpy as np

# Assuming df is your DataFrame containing the 'quantity' column

# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['quantity'].quantile(0.0)
Q3 = df['quantity'].quantile(0.55)

# Calculate the interquartile range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# # Create a mask to identify outliers
outliers_mask = (df['quantity'] < lower_bound) | (df['quantity'] > upper_bound)

# # Create a new column for log-transformed outliers
df['quantity_log'] = df['quantity']

# # Apply log transformation to outliers
df.loc[outliers_mask, 'quantity_log'] = np.log(df.loc[outliers_mask, 'quantity'])
# Out:
# C:\Users\kgayu\AppData\Local\Temp\ipykernel_21580\3304915904.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quantity_log'] = df['quantity']

# %%
df['quantity_log'].describe()
# Out:
# count    483018.000000
# mean        582.387845
# std         604.165513
# min           1.000000
# 25%          54.000000
# 50%         413.000000
# 75%         941.000000
# max        2393.000000
# Name: quantity_log, dtype: float64

# %% [markdown]
# 5)WINSORZATION
#
# Is a data transformation technique used to mitigate the impact of extreme values (outliers) in a dataset by replacing them with less extreme values within a specified range, typically determined by percentiles. It helps stabilize statistical measures by reducing the influence of outliers while preserving the overall distribution of the data.

# %%
import numpy as np
new_win=df.copy()

def winsorize(data, lower_percentile=0, upper_percentile=88):
    # Calculate percentiles
    lower_bound = np.percentile(data, lower_percentile)
    upper_bound = np.percentile(data, upper_percentile)
    
    # Winsorize the data
    winsorized_data = np.where(data < lower_bound, lower_bound,
                               np.where(data > upper_bound, upper_bound, data))
    
    return winsorized_data
new_win['quantity']=winsorize(new_win['quantity'])

# %%
new_win['quantity'].describe()
# Out:
# count    483018.000000
# mean       1401.104334
# std        1412.704087
# min           1.000000
# 25%         359.000000
# 50%         804.000000
# 75%        2008.000000
# max        4349.000000
# Name: quantity, dtype: float64

# %%
# Outlier detection using boxplots 
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize= (20,14))
plt.subplot(3,3,1)
plt.title('Original')
sns.boxplot(x=df['quantity'])

plt.subplot(3,3,2)
plt.title('Trimming')
sns.boxplot(x=df_no_outliers['quantity'])

plt.subplot(3,3,3)
plt.title('Capping')
sns.boxplot(x=df_cap['quantity'])

plt.subplot(3,3,4)
plt.title('Flooring')
sns.boxplot(x=df_floor['quantity'])

plt.subplot(3,3,5)
plt.title('Tranforming')
sns.boxplot(x=df['quantity_log'])

plt.subplot(3,3,6)
plt.title('Winsorzation')
sns.boxplot(x=new_win['quantity'])
# Out:
# <Axes: title={'center': 'Winsorzation'}, xlabel='quantity'>

# %% [markdown]
# So Winsorization is the best compared to other methods

# %%
new_win.to_csv('US-Updated.csv')

# %%
# %pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\kgayu\anaconda3\lib\site-packages (0.14.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: fiona>=1.8.21 in c:\users\kgayu\anaconda3\lib\site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: numpy>=1.22 in c:\users\kgayu\anaconda3\lib\site-packages (from geopandas) (1.24.3)
# Requirement already satisfied: packaging in c:\users\kgayu\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\kgayu\anaconda3\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\kgayu\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\kgayu\anaconda3\lib\site-packages (from geopandas) (2.0.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\kgayu\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\kgayu\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in c:\users\kgayu\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\kgayu\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\kgayu\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\kgayu\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kgayu\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kgayu\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kgayu\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\kgayu\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)

# %% [markdown]
# ****world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))****
# This line of code loads the world shapefile using GeoPandas. The shapefile is sourced from the Natural Earth dataset, which provides public domain map datasets available at various resolutions

# %% [markdown]
# All countries that export Crude oil to US

# %%
import geopandas as gpd

# Load the world shapefile
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

country_counts = df[df['originTypeName'] == 'Country']['originName']

# Filter the world dataframe to only include the countries in US dataset
world_subset = world[world['name'].isin(country_counts)]

# Plot the world map
world.plot(color='grey',edgecolor='white',figsize=(30, 20))

# Overlay the countries from US dataset
world_subset.plot(ax=plt.gca(), color='darkblue', edgecolor='white')

# Show the plot
plt.show()
# Out:
# C:\Users\kgayu\AppData\Local\Temp\ipykernel_21580\1037582961.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# TOP 10 Countries with Highest exports to US

# %%
# Load the world shapefile
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

country_counts = df[df['originTypeName'] == 'Country']['originName'].value_counts()

# Get the top 10 origin with the highest counts
top_10_countries = country_counts.head(10)

# Filter the world dataframe to include only the geometries for the top 10 origin
highlighted_countries = world[world['name'].isin(top_10_countries.index)]

# Plot the world map
world.plot(color='lightgrey', edgecolor='white', figsize=(20, 15))

# Plot the highlighted origin
highlighted_countries.plot(color='lightgreen', ax=plt.gca())

# Annotate each origin with its count for the top 10 countries
for idx, row in highlighted_countries.iterrows():
    country_name = row['name']
    count = top_10_countries.get(country_name, 0)
    plt.text(row.geometry.centroid.x, row.geometry.centroid.y, 
             f"{country_name}: ", 
             ha='right', fontsize=12, color='blue', fontweight='bold')  # Country name in blue and bold
    plt.text(row.geometry.centroid.x, row.geometry.centroid.y, 
             f"{count}", 
             ha='left', fontsize=12, color='darkgreen', fontweight='bold')
plt.title('Top 10 countries that export highest Crude oil to US')
# Show the plot
plt.show()
# Out:
# C:\Users\kgayu\AppData\Local\Temp\ipykernel_21580\1199595677.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
country_counts.head(10)
# Out:
# originName
# Canada          57962
# Saudi Arabia    11647
# Mexico          10827
# Colombia         8172
# Iraq             7164
# Venezuela        7119
# Nigeria          6859
# Brazil           6689
# Angola           6431
# Russia           4446
# Name: count, dtype: int64

# %% [markdown]
# ountries which has to improve the crude oil exports to US

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the world shapefile
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

country_counts = df[df['originTypeName'] == 'Country']['originName'].value_counts()

# Get the top 10 origin with the highest counts
least_countries = country_counts.tail(10)

# Filter the world dataframe to include only the geometries for the top 10 origin
highlighted_countries = world[world['name'].isin(least_countries.index)]

# Plot the world map
world.plot(color='lightgrey', edgecolor='white', figsize=(20, 15))

# Plot the highlighted origin
highlighted_countries.plot(color='pink', ax=plt.gca())

# Annotate each origin with its count for the least 10 countries
for idx, row in highlighted_countries.iterrows():
    country_name = row['name']
    count = least_countries.get(country_name, 0)
    plt.text(row.geometry.centroid.x, row.geometry.centroid.y, 
             f"{country_name}: ", 
             ha='right', fontsize=12, color='blue', fontweight='bold')  # Country name in blue and bold
    plt.text(row.geometry.centroid.x, row.geometry.centroid.y, 
             f"{count}", 
             ha='left', fontsize=12, color='red', fontweight='bold')
    plt.title('Countries that should imporve exports to US')
# Show the plot
plt.show()
# Out:
# C:\Users\kgayu\AppData\Local\Temp\ipykernel_21580\68704462.py:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
least_countries
# Out:
# originName
# Yemen               35
# Sudan               35
# Syria               28
# Tunisia             27
# Bahamas             18
# Papua New Guinea     7
# Barbados             7
# Spain                7
# South Africa         7
# Panama               7
# Name: count, dtype: int64
